# %% [markdown]
# # K Means Clustering for Unsupervised Classification of Synthetic Blob Data
# K Means Clustering used here employs distance based similarity metric based on 2-norm distance to assign the data point to any cluster. I use a centroid based metric
# The algorithm begins by specifying the number of cluster that the data is desired to be grouped into. The algorithm then randomly assigns each observation to a cluster, and finds the centroid of each cluster. Then, the algorithm iterates through two steps:
#
# Reassign data points to the cluster whose centroid is closest. Calculate new centroid of each cluster. Repeat these 2 steps till the within cluster variation cannot be reduced any further. The within cluster variation is calculated as the sum of the euclidean distance between the data points and their respective cluster centroids.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Blob Dataset Creation fom sci-kit

# %%
from sklearn.datasets import make_blobs

# %%
# Create Data
data = make_blobs(n_samples=200, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=101)

# %% [markdown]
# # Synthetic Blob Data Visualization

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# K-means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.46941837, -6.56081545],
#        [ 3.71749226,  7.01388735],
#        [-4.13591321,  7.95389851],
#        [-0.0123077 ,  2.13407664]])

# %%
kmeans.labels_
# Out:
# array([2, 1, 3, 1, 1, 0, 1, 3, 1, 3, 2, 3, 1, 1, 2, 3, 1, 3, 0, 2, 0, 3,
#        3, 0, 2, 0, 0, 3, 1, 1, 2, 0, 1, 3, 3, 2, 0, 0, 0, 3, 0, 2, 2, 2,
#        3, 1, 2, 3, 0, 3, 3, 2, 1, 3, 0, 2, 3, 3, 2, 1, 0, 1, 0, 2, 1, 3,
#        0, 1, 1, 0, 1, 3, 0, 3, 0, 1, 1, 3, 2, 3, 3, 0, 1, 0, 3, 3, 3, 2,
#        3, 0, 0, 0, 0, 3, 3, 0, 1, 2, 0, 1, 3, 0, 3, 3, 1, 3, 0, 1, 0, 0,
#        1, 2, 2, 1, 0, 1, 2, 2, 1, 2, 3, 2, 3, 2, 3, 1, 2, 3, 0, 2, 2, 2,
#        3, 0, 0, 2, 1, 2, 1, 3, 0, 1, 0, 2, 2, 1, 3, 0, 2, 2, 2, 2, 3, 1,
#        3, 2, 1, 1, 1, 3, 1, 3, 3, 2, 0, 2, 3, 1, 2, 3, 1, 3, 2, 1, 3, 2,
#        1, 1, 0, 1, 2, 0, 0, 2, 0, 0, 0, 0, 0, 3, 0, 1, 1, 2, 0, 3, 1, 1,
#        0, 3])

# %%
exec(open('kmc_classifier.py').read())

# %%
k = 4;
noit = 500;
p=2;
X=data[0];#Array extraction from tuple
mu, y_pred, wcss = kmc(X, k,noit,p)#KMC from my library using wcss-within cluster sum of squares
# Out:
# INITIAL CENTROIDS [[[-4.11495481  8.02621345]]
#
#  [[-8.33457235 -6.0539155 ]]
#
#  [[ 2.39250023  5.38173971]]
#
#  [[ 0.75660108  5.00732585]]]
# FINAL CENTROIDS for 4 clusters =[[[-4.13591321  7.95389851]]
#
#  [[-9.46941837 -6.56081545]]
#
#  [[ 3.71749226  7.01388735]]
#
#  [[-0.05357282  2.15299364]]]:
# WCSS for k=4 =5305659697.473136
# BCSS for k=4 =239.1231987174368
# Gap Statistic= [[34237492.11617718]
#  [70948822.62346506]
#  [33020858.1113922 ]
#  [ 2842576.19080384]]

# %%
y_pred
# Out:
# array([0., 2., 3., 2., 2., 1., 2., 3., 2., 3., 0., 3., 2., 2., 0., 3., 2.,
#        3., 1., 0., 1., 3., 3., 1., 0., 1., 1., 3., 2., 2., 0., 1., 2., 3.,
#        3., 0., 1., 1., 1., 3., 1., 0., 0., 0., 3., 2., 0., 3., 1., 3., 3.,
#        0., 2., 3., 1., 0., 3., 3., 0., 2., 1., 2., 1., 0., 2., 3., 1., 2.,
#        2., 1., 2., 3., 1., 3., 1., 2., 2., 3., 0., 3., 3., 1., 2., 1., 3.,
#        3., 3., 0., 3., 1., 1., 1., 1., 3., 3., 1., 2., 0., 1., 2., 3., 1.,
#        3., 3., 2., 3., 1., 2., 1., 1., 2., 0., 0., 2., 1., 2., 0., 0., 2.,
#        0., 3., 0., 3., 0., 3., 2., 0., 3., 1., 0., 0., 0., 3., 1., 1., 0.,
#        2., 0., 2., 3., 1., 2., 1., 0., 0., 2., 3., 1., 0., 0., 0., 0., 3.,
#        2., 3., 0., 2., 2., 2., 3., 2., 3., 3., 0., 1., 0., 3., 2., 0., 3.,
#        2., 3., 0., 2., 3., 0., 2., 2., 1., 2., 0., 1., 1., 0., 1., 1., 1.,
#        1., 1., 3., 1., 2., 2., 0., 1., 3., 2., 2., 1., 0.])

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True,figsize=(10,6))
ax1.set_title('K-Means from library')
ax1.scatter(data[0][:,0],data[0][:,1],c=y_pred,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
ax3.set_title("K-Means Sci-kit")
ax3.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
#Colors may be different but the regions on the axis should be compared
